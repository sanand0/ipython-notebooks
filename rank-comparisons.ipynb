# %% [markdown]
# # A pattern for comparisons
#
# [Doing business](https://gramener.com/playground/doingbusiness/) is an interesting analysis of the [ease of doing business data](https://gramener.com/playground/doingbusiness/doingbusiness.csv). It shows how each country fares relative to others.
#
# Another way of doing the same is through radar charts.

# %%
import os
import vis              # The Gramener visualisation server
import layout           # The Gramener visualisation server
import color as _color  # The Gramener visualisation server
import urllib
import pandas as pd
import orderedattrdict
from IPython.display import HTML

# %%
if not os.path.exists('doingbusiness.csv'):
    urllib.urlretrieve('https://gramener.com/playground/doingbusiness/doingbusiness.csv', 'doingbusiness.csv')

data = pd.read_csv('doingbusiness.csv', encoding='utf-8')
ranks = data.set_index('Country')[[col for col in data.columns if 'Rank' in col]]
ease = ranks.max().max() - ranks

plot_args = {
    'width': 240,
    'height': 240,
    'color': ['rgba(255, 0, 0, 0.5)', 'rgba(0, 0, 255, 0.5)'],
    'radar': True,
    'stack': None
}
def radar(*countries, **kwargs):
    result = []
    if kwargs.get('split'):
        for country in countries:
            result.append(vis.SVG('areaplot.svg', data=ease.T[[country]], **plot_args))
    result.append(vis.SVG('areaplot.svg', data=ease.T[list(countries)], **plot_args))
    if kwargs.get('table'):
        data = ranks.ix[list(countries)]
        diff = data.irow(1) - data.irow(0)
        diff.name = 'Diff'        
        result.append(data.append(diff.to_frame().T).to_html())
    return HTML(''.join(result))

# %% [markdown]
# ### Here is how Italy and Pakistan compare
#
# Italy's generally better for business, but Pakistan is better for dealing with construction permits and protecting minority investors.

# %%
radar('Italy', 'Pakistan', table=True, split=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" width="240.0000" height="240.0000">
#
#
#
#
#   <path
#
#         d="M120.0,28.085106383L120.0000,28.0851 L72.0325,45.3611 L60.1965,92.6887 L37.8659,131.8091 L40.4051,188.9694 L103.4557,176.3447 L147.5139,213.7037 L145.0845,141.7358 L238.7786,137.0778 L165.2881,99.3176 L177.2849,30.8629 L120.0000,28.0851z
#            M120.0,120.0L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000z"
#
#     stroke="none" fill="rgba(255, 0, 0, 0.5)"
#   />
#
# </svg><svg xmlns="http://www.w3.org/2000/svg" width="240.0000" height="240.0000">
#
#
#
#
#   <path
#
#         d="M120.0,82.6829268293L120.0000,82.6829 L93.4954,78.7581 L34.8052,81.0928 L96.8237,123.3322 L91.2447,144.9167 L108.4558,159.3158 L153.8079,235.1392 L129.9538,128.6250 L134.4852,122.0827 L145.2922,108.4494 L157.5811,61.5226 L120.0000,82.6829z
#            M120.0,120.0L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000z"
#
#     stroke="none" fill="rgba(255, 0, 0, 0.5)"
#   />
#
# </svg><svg xmlns="http://www.w3.org/2000/svg" width="240.0000" height="240.0000">
#
#
#
#
#   <path
#
#         d="M120.0,28.085106383L120.0000,28.0851 L72.0325,45.3611 L60.1965,92.6887 L37.8659,131.8091 L40.4051,188.9694 L103.4557,176.3447 L147.5139,213.7037 L145.0845,141.7358 L238.7786,137.0778 L165.2881,99.3176 L177.2849,30.8629 L120.0000,28.0851z
#            M120.0,120.0L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000z"
#
#     stroke="none" fill="rgba(255, 0, 0, 0.5)"
#   />
#
#
#
#   <path
#
#         d="M120.0,87.4468085106L120.0000,87.4468 L96.8790,84.0230 L45.6811,86.0597 L99.7824,122.9069 L94.9155,141.7358 L109.9296,154.2968 L149.4920,220.4405 L128.6831,127.5239 L132.6360,121.8168 L142.0634,109.9240 L152.7835,68.9878 L120.0000,87.4468z
#            M120.0,28.085106383L120.0000,28.0851 L177.2849,30.8629 L165.2881,99.3176 L238.7786,137.0778 L145.0845,141.7358 L147.5139,213.7037 L103.4557,176.3447 L40.4051,188.9694 L37.8659,131.8091 L60.1965,92.6887 L72.0325,45.3611 L120.0000,28.0851z"
#
#     stroke="none" fill="rgba(0, 0, 255, 0.5)"
#   />
#
# </svg><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ease of Doing Business Rank</th>
#       <th>Starting a Business Rank</th>
#       <th>Dealing with Construction Permits Rank</th>
#       <th>Getting Electricity Rank</th>
#       <th>Registering Property Rank</th>
#       <th>Getting Credit Rank</th>
#       <th>Protecting Minority Investors Rank</th>
#       <th>Paying Taxes Rank</th>
#       <th>Trading Across Borders Rank</th>
#       <th>Enforcing Contracts Rank</th>
#       <th>Resolving Insolvency Rank</th>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Italy</th>
#       <td>45</td>
#       <td>50</td>
#       <td>86</td>
#       <td>59</td>
#       <td>24</td>
#       <td>97</td>
#       <td>36</td>
#       <td>137</td>
#       <td>1</td>
#       <td>111</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>Pakistan</th>
#       <td>138</td>
#       <td>122</td>
#       <td>61</td>
#       <td>157</td>
#       <td>137</td>
#       <td>133</td>
#       <td>25</td>
#       <td>171</td>
#       <td>169</td>
#       <td>151</td>
#       <td>94</td>
#     </tr>
#     <tr>
#       <th>Diff</th>
#       <td>93</td>
#       <td>72</td>
#       <td>-25</td>
#       <td>98</td>
#       <td>113</td>
#       <td>36</td>
#       <td>-11</td>
#       <td>34</td>
#       <td>168</td>
#       <td>40</td>
#       <td>71</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Here's how the US and Pakistan compare
#
# It's actually easier to start a business in Pakistan than in the US -- though in every other parameter, the US is ahead.

# %%
radar('United States', 'Pakistan', table=True, split=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" width="240.0000" height="240.0000">
#
#
#
#
#   <path
#
#         d="M120.0,3.20855614973L120.0000,3.2086 L71.4291,44.4221 L28.9395,78.4141 L27.8990,133.2421 L44.8292,185.1359 L86.1921,235.1392 L147.8418,214.8205 L185.9563,177.1515 L218.4528,134.1554 L218.0651,75.2152 L183.8361,20.6691 L120.0000,3.2086z
#            M120.0,120.0L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000z"
#
#     stroke="none" fill="rgba(255, 0, 0, 0.5)"
#   />
#
# </svg><svg xmlns="http://www.w3.org/2000/svg" width="240.0000" height="240.0000">
#
#
#
#
#   <path
#
#         d="M120.0,82.6829268293L120.0000,82.6829 L93.4954,78.7581 L34.8052,81.0928 L96.8237,123.3322 L91.2447,144.9167 L108.4558,159.3158 L153.8079,235.1392 L129.9538,128.6250 L134.4852,122.0827 L145.2922,108.4494 L157.5811,61.5226 L120.0000,82.6829z
#            M120.0,120.0L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000z"
#
#     stroke="none" fill="rgba(255, 0, 0, 0.5)"
#   />
#
# </svg><svg xmlns="http://www.w3.org/2000/svg" width="240.0000" height="240.0000">
#
#
#
#
#   <path
#
#         d="M120.0,3.20855614973L120.0000,3.2086 L71.4291,44.4221 L28.9395,78.4141 L27.8990,133.2421 L44.8292,185.1359 L86.1921,235.1392 L147.8418,214.8205 L185.9563,177.1515 L218.4528,134.1554 L218.0651,75.2152 L183.8361,20.6691 L120.0000,3.2086z
#            M120.0,120.0L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000 L120.0000,120.0000z"
#
#     stroke="none" fill="rgba(255, 0, 0, 0.5)"
#   />
#
#
#
#   <path
#
#         d="M120.0,87.2727272727L120.0000,87.2727 L96.7553,83.8306 L45.2837,85.8782 L99.6743,122.9224 L94.7814,141.8520 L109.8757,154.4802 L149.6497,220.9777 L128.7295,127.5642 L132.7036,121.8265 L142.1814,109.8701 L152.9589,68.7150 L120.0000,87.2727z
#            M120.0,3.20855614973L120.0000,3.2086 L183.8361,20.6691 L218.0651,75.2152 L218.4528,134.1554 L185.9563,177.1515 L147.8418,214.8205 L86.1921,235.1392 L44.8292,185.1359 L27.8990,133.2421 L28.9395,78.4141 L71.4291,44.4221 L120.0000,3.2086z"
#
#     stroke="none" fill="rgba(0, 0, 255, 0.5)"
#   />
#
# </svg><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ease of Doing Business Rank</th>
#       <th>Starting a Business Rank</th>
#       <th>Dealing with Construction Permits Rank</th>
#       <th>Getting Electricity Rank</th>
#       <th>Registering Property Rank</th>
#       <th>Getting Credit Rank</th>
#       <th>Protecting Minority Investors Rank</th>
#       <th>Paying Taxes Rank</th>
#       <th>Trading Across Borders Rank</th>
#       <th>Enforcing Contracts Rank</th>
#       <th>Resolving Insolvency Rank</th>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>United States</th>
#       <td>7</td>
#       <td>49</td>
#       <td>33</td>
#       <td>44</td>
#       <td>34</td>
#       <td>2</td>
#       <td>35</td>
#       <td>53</td>
#       <td>34</td>
#       <td>21</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Pakistan</th>
#       <td>138</td>
#       <td>122</td>
#       <td>61</td>
#       <td>157</td>
#       <td>137</td>
#       <td>133</td>
#       <td>25</td>
#       <td>171</td>
#       <td>169</td>
#       <td>151</td>
#       <td>94</td>
#     </tr>
#     <tr>
#       <th>Diff</th>
#       <td>131</td>
#       <td>73</td>
#       <td>28</td>
#       <td>113</td>
#       <td>103</td>
#       <td>131</td>
#       <td>-10</td>
#       <td>118</td>
#       <td>135</td>
#       <td>130</td>
#       <td>89</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Types of patterns
#
# Some patterns are more interesting than others. Here are some thoughts:
#
# ## Comparison patterns
#
# - Create a matrix between every pair of entities. Each cell shows a metric. The metric could be:
#     - difference metric: how different are the countries on average? e.g. the % of parameters on which country X is ahead of country Y.
#     - variation metric: how dissimilar are the countries, e.g. is country X well ahead of country Y on some parameters, but the exact opposite is true on others
#     - similarity metric: how similar are the countries
# - Visualise the matrix in different ways:
#     - List the top 10 pairs based on metric
#     - Network diagram
#     - Heatgrid
#     - Tree based on hierarchical clustering
#     - Extend this by surveying linear algebra / graph theory literature
#
# ## Contrast / exception patterns
#
# - Countries that are very high in most areas, low in few (or the opposite)
# - Beats others in most, but beaten by X in just one or a few
#
# - Discretisation into quartiles

# %% [markdown]
# # Comparisons
#
# ## Difference metric
#
# The "difference" between two countries can be defined in many ways. Here's one metric: country X leads country Y by the % of areas X is ahead of Y on. In the above example:
#
# - Italy leads Pakistan in 9 areas
# - Pakistan leads Italy in 2 areas
# - Italy leads Pakistan overall in 9 - 2 = 7 areas, which is ~63% (7/11)

# %%
count = len(ranks.columns)
def lead(a, b):
    diff = ranks.ix[a] - ranks.ix[b]
    return float((diff < 0).sum() - (diff > 0).sum()) / count

lead('Italy', 'Pakistan')
# Out:
# 0.6363636363636364

# %% [markdown]
# Let's compute the lead for every pair of countries.

# %%
# Warning: unoptimised, slow computation
def pairwise(method):
    result = {}
    for a in ranks.index:
        for b in ranks.index:
            result[a, b] = method(a, b)
    result = pd.Series(result).reset_index()
    result.columns = ['Country X', 'Country Y', 'Metric']
    return result.pivot_table(index='Country X', columns='Country Y', values='Metric')

# %% [markdown]
# This is the pairwise difference for the first few countries (alphabetically), shown as a matrix. For each country, read horizontally to see which countries it is better than.

# %%
# Warning: slow computation
differences = pairwise(lead)

# %%
HTML('<style>.matrix text { font-size: 11px }</style>' +
     vis.SVG('clusterplot.svg', width=600, height=600, cls='matrix', gradient=_color.RdYlGn,
             data=diff_pivot.head(20).T.head(20),
             distance=True, dendrogram=False, label=100))
# Out:
# <style>.matrix text { font-size: 11px }</style><svg xmlns="http://www.w3.org/2000/svg" width="600.0000" height="600.0000" class="matrix">
#
# <g class="highlight"><rect/><rect/><rect/><rect/></g>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       <rect x="25.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#f4c796"/>
#
#
#
#           <text x="37.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-27</text>
#
#
#
#
#
#
#
#
#
#       <rect x="50.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#f4c796"/>
#
#
#
#           <text x="62.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-27</text>
#
#
#
#
#
#
#
#
#
#       <rect x="75.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#97d08d"/>
#
#
#
#           <text x="87.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#000">45</text>
#
#
#
#
#
#
#
#
#
#       <rect x="100.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#eda17a"/>
#
#
#
#           <text x="112.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-45</text>
#
#
#
#
#
#
#
#
#
#       <rect x="125.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#e67b5e"/>
#
#
#
#           <text x="137.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-64</text>
#
#
#
#
#
#
#
#
#
#       <rect x="150.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#D73027"/>
#
#
#
#           <text x="162.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#fff">-100</text>
#
#
#
#
#
#
#
#
#
#       <rect x="175.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#D73027"/>
#
#
#
#           <text x="187.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#fff">-100</text>
#
#
#
#
#
#
#
#
#
#       <rect x="200.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#de5643"/>
#
#
#
#           <text x="212.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#fff">-82</text>
#
#
#
#
#
#
#
#
#
#       <rect x="225.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#de5643"/>
#
#
#
#           <text x="237.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#fff">-82</text>
#
#
#
#
#
#
#
#
#
#       <rect x="250.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#e67b5e"/>
#
#
#
#           <text x="262.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-64</text>
#
#
#
#
#
#
#
#
#
#       <rect x="275.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#e67b5e"/>
#
#
#
#           <text x="287.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-64</text>
#
#
#
#
#
#
#
#
#
#       <rect x="300.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#fbecb1"/>
#
#
#
#           <text x="312.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-9</text>
#
#
#
#
#
#
#
#
#
#       <rect x="325.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#eda17a"/>
#
#
#
#           <text x="337.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-45</text>
#
#
#
#
#
#
#
#
#
#       <rect x="350.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#de5643"/>
#
#
#
#           <text x="362.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#fff">-82</text>
#
#
#
#
#
#
#
#
#
#       <rect x="375.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#e26850"/>
#
#
#
#           <text x="387.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-73</text>
#
#
#
#
#
#
#
#
#
#       <rect x="400.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#e67b5e"/>
#
#
#
#           <text x="412.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-64</text>
#
#
#
#
#
#
#
#
#
#       <rect x="425.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#f4c796"/>
#
#
#
#           <text x="437.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-27</text>
#
#
#
#
#
#
#
#
#
#       <rect x="450.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#e67b5e"/>
#
#
#
#           <text x="462.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-64</text>
#
#
#
#
#
#
#
#
#
#       <rect x="475.0"
#             y="0.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#eda17a"/>
#
#
#
#           <text x="487.5" y="15.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-45</text>
#
#
#
#
#
#
#     <text class="title" x="505" y="15.0" text-anchor="start" dominant-baseline="middle">Afghanistan</text>
#
#
#
#
#
#
#
#       <rect x="0.0"
#             y="30.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#c1e3a1"/>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       <rect x="50.0"
#             y="30.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#6dbd78"/>
#
#
#
#           <text x="62.5" y="45.0" dominant-baseline="middle" text-anchor="middle" fill="#000">64</text>
#
#
#
#
#
#
#
#
#
#       <rect x="75.0"
#             y="30.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#6dbd78"/>
#
#
#
#           <text x="87.5" y="45.0" dominant-baseline="middle" text-anchor="middle" fill="#000">64</text>
#
#
#
#
#
#
#
#
#
#       <rect x="100.0"
#             y="30.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#97d08d"/>
#
#
#
#           <text x="112.5" y="45.0" dominant-baseline="middle" text-anchor="middle" fill="#000">45</text>
#
#
#
#
#
#
#
#
#
#       <rect x="125.0"
#             y="30.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#97d08d"/>
#
#
#
#           <text x="137.5" y="45.0" dominant-baseline="middle" text-anchor="middle" fill="#000">45</text>
#
#
#
#
#
#
#
#
#
#       <rect x="150.0"
#             y="30.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#e98e6c"/>
#
#
#
#           <text x="162.5" y="45.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-55</text>
#
#
#
#
#
#
#
#
#
#       <rect x="175.0"
#             y="30.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#e67b5e"/>
#
#
#
#           <text x="187.5" y="45.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-64</text>
#
#
#
#
#
#
#
#
#
#       <rect x="200.0"
#             y="30.0"
#         width="25.0"
#        height="30.0" stroke="#fff" fill="#eda17a"/>
#
#
#
#           <text x="212.5" y="45.0" dominant-baseline="middle" text-anchor="middle" fill="#000">-45</text>

# %% [markdown]
# ### Pareto sub-optimal countries
#
# Are there countries that are worse than other countries in every way? Hence we'd never invest in them? In the above graph, that's where the values are 100 or -100. We can drop all other patterns and just look for these.
#
# However, there are still too many of these countries.
#
# Another approach is to see if these pareto optimal countries form a tree. The short answer is NO.

# %%
pareto_optimal_countries = (diff_pivot >= 1).sum(axis=1) > 0
diff_pareto = diff_pivot[pareto_optimal_countries].T[pareto_optimal_countries].T
HTML(vis.SVG('clusterplot.svg', width=600, height=500, cls='matrix', gradient=_color.RdYlGn,
             data=diff_pareto.head(20).T.head(20),
             distance=True, dendrogram=False, label=100))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" width="600.0000" height="500.0000" class="matrix">
#
# <g class="highlight"><rect/><rect/><rect/><rect/></g>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       <rect x="25.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#c1e3a1"/>
#
#
#
#           <text x="37.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">27</text>
#
#
#
#
#
#
#
#
#
#       <rect x="50.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#e67b5e"/>
#
#
#
#           <text x="62.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-64</text>
#
#
#
#
#
#
#
#
#
#       <rect x="75.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#e26850"/>
#
#
#
#           <text x="87.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-73</text>
#
#
#
#
#
#
#
#
#
#       <rect x="100.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#D73027"/>
#
#
#
#           <text x="112.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#fff">-100</text>
#
#
#
#
#
#
#
#
#
#       <rect x="125.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#eda17a"/>
#
#
#
#           <text x="137.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-45</text>
#
#
#
#
#
#
#
#
#
#       <rect x="150.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#eaf6b5"/>
#
#
#
#           <text x="162.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">9</text>
#
#
#
#
#
#
#
#
#
#       <rect x="175.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#f4c796"/>
#
#
#
#           <text x="187.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-27</text>
#
#
#
#
#
#
#
#
#
#       <rect x="200.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#e67b5e"/>
#
#
#
#           <text x="212.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-64</text>
#
#
#
#
#
#
#
#
#
#       <rect x="225.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#eda17a"/>
#
#
#
#           <text x="237.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-45</text>
#
#
#
#
#
#
#
#
#
#       <rect x="250.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#f8d9a3"/>
#
#
#
#           <text x="262.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-18</text>
#
#
#
#
#
#
#
#
#
#       <rect x="275.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#fbecb1"/>
#
#
#
#           <text x="287.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-9</text>
#
#
#
#
#
#
#
#
#
#       <rect x="300.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#fbecb1"/>
#
#
#
#           <text x="312.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-9</text>
#
#
#
#
#
#
#
#
#
#       <rect x="325.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#e67b5e"/>
#
#
#
#           <text x="337.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-64</text>
#
#
#
#
#
#
#
#
#
#       <rect x="350.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#e67b5e"/>
#
#
#
#           <text x="362.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-64</text>
#
#
#
#
#
#
#
#
#
#       <rect x="375.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#e67b5e"/>
#
#
#
#           <text x="387.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-64</text>
#
#
#
#
#
#
#
#
#
#       <rect x="400.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#f4c796"/>
#
#
#
#           <text x="412.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-27</text>
#
#
#
#
#
#
#
#
#
#       <rect x="425.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#e67b5e"/>
#
#
#
#           <text x="437.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-64</text>
#
#
#
#
#
#
#
#
#
#       <rect x="450.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#eda17a"/>
#
#
#
#           <text x="462.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-45</text>
#
#
#
#
#
#
#
#
#
#       <rect x="475.0"
#             y="0.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#e67b5e"/>
#
#
#
#           <text x="487.5" y="12.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-64</text>
#
#
#
#
#
#
#     <text class="title" x="505" y="12.5" text-anchor="start" dominant-baseline="middle">Antigua and Barbuda</text>
#
#
#
#
#
#
#
#       <rect x="0.0"
#             y="25.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#f4c796"/>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       <rect x="50.0"
#             y="25.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#e26850"/>
#
#
#
#           <text x="62.5" y="37.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-73</text>
#
#
#
#
#
#
#
#
#
#       <rect x="75.0"
#             y="25.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#de5643"/>
#
#
#
#           <text x="87.5" y="37.5" dominant-baseline="middle" text-anchor="middle" fill="#fff">-82</text>
#
#
#
#
#
#
#
#
#
#       <rect x="100.0"
#             y="25.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#D73027"/>
#
#
#
#           <text x="112.5" y="37.5" dominant-baseline="middle" text-anchor="middle" fill="#fff">-100</text>
#
#
#
#
#
#
#
#
#
#       <rect x="125.0"
#             y="25.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#eda17a"/>
#
#
#
#           <text x="137.5" y="37.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-45</text>
#
#
#
#
#
#
#
#
#
#       <rect x="150.0"
#             y="25.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#fbecb1"/>
#
#
#
#           <text x="162.5" y="37.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-9</text>
#
#
#
#
#
#
#
#
#
#       <rect x="175.0"
#             y="25.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#eda17a"/>
#
#
#
#           <text x="187.5" y="37.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-45</text>
#
#
#
#
#
#
#
#
#
#       <rect x="200.0"
#             y="25.0"
#         width="25.0"
#        height="25.0" stroke="#fff" fill="#eda17a"/>
#
#
#
#           <text x="212.5" y="37.5" dominant-baseline="middle" text-anchor="middle" fill="#000">-45</text>
#
#
#
#
#
#
#
#
#
#       <rect

# %% [markdown]
# ## Variation metric

# %%
def variation(a, b):
    diff = ranks.ix[a] - ranks.ix[b]
    a_b = diff[diff > 0].abs().sum()
    b_a = diff[diff < 0].abs().sum()
    return abs(a_b - b_a)

# %%
# Warning: slow computation
variations = pairwise(variation)
variations = 1 - variations / float(variations.max().max())

# %%
variations

# %%
high_variation_countries = (variations >= 0.95).any(axis=1)
high_variations = variations[high_variation_countries].T[high_variation_countries].T

# %%
# Show only the highest variations
HTML(vis.SVG('clusterplot.svg', width=600, height=500, cls='matrix', gradient=_color.Blues,
             data=high_variations,
             distance=True, dendrogram=False, label=100))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" width="600.0000" height="500.0000" class="matrix">
#
# <g class="highlight"><rect/><rect/><rect/><rect/></g>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       <rect x="45.4545454545"
#             y="0.0"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#e7f2fa"/>
#
#
#
#           <text x="68.1818181818" y="22.7272727273" dominant-baseline="middle" text-anchor="middle" fill="#000">6</text>
#
#
#
#
#
#
#
#
#
#       <rect x="90.9090909091"
#             y="0.0"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#113b75"/>
#
#
#
#           <text x="113.636363636" y="22.7272727273" dominant-baseline="middle" text-anchor="middle" fill="#fff">96</text>
#
#
#
#
#
#
#
#
#
#       <rect x="136.363636364"
#             y="0.0"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#c2deef"/>
#
#
#
#           <text x="159.090909091" y="22.7272727273" dominant-baseline="middle" text-anchor="middle" fill="#000">19</text>
#
#
#
#
#
#
#
#
#
#       <rect x="181.818181818"
#             y="0.0"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#e0eef8"/>
#
#
#
#           <text x="204.545454545" y="22.7272727273" dominant-baseline="middle" text-anchor="middle" fill="#000">8</text>
#
#
#
#
#
#
#
#
#
#       <rect x="227.272727273"
#             y="0.0"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#154179"/>
#
#
#
#           <text x="250.0" y="22.7272727273" dominant-baseline="middle" text-anchor="middle" fill="#fff">93</text>
#
#
#
#
#
#
#
#
#
#       <rect x="272.727272727"
#             y="0.0"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#16427a"/>
#
#
#
#           <text x="295.454545455" y="22.7272727273" dominant-baseline="middle" text-anchor="middle" fill="#fff">93</text>
#
#
#
#
#
#
#
#
#
#       <rect x="318.181818182"
#             y="0.0"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#b8d9ed"/>
#
#
#
#           <text x="340.909090909" y="22.7272727273" dominant-baseline="middle" text-anchor="middle" fill="#000">22</text>
#
#
#
#
#
#
#
#
#
#       <rect x="363.636363636"
#             y="0.0"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#113b74"/>
#
#
#
#           <text x="386.363636364" y="22.7272727273" dominant-baseline="middle" text-anchor="middle" fill="#fff">96</text>
#
#
#
#
#
#
#
#
#
#       <rect x="409.090909091"
#             y="0.0"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#0d3670"/>
#
#
#
#           <text x="431.818181818" y="22.7272727273" dominant-baseline="middle" text-anchor="middle" fill="#fff">98</text>
#
#
#
#
#
#
#
#
#
#       <rect x="454.545454545"
#             y="0.0"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#badaed"/>
#
#
#
#           <text x="477.272727273" y="22.7272727273" dominant-baseline="middle" text-anchor="middle" fill="#000">22</text>
#
#
#
#
#
#
#     <text class="title" x="505" y="22.7272727273" text-anchor="start" dominant-baseline="middle">Central African Republic</text>
#
#
#
#
#
#
#
#       <rect x="0.0"
#             y="45.4545454545"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#e7f2fa"/>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       <rect x="90.9090909091"
#             y="45.4545454545"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#154079"/>
#
#
#
#           <text x="113.636363636" y="68.1818181818" dominant-baseline="middle" text-anchor="middle" fill="#fff">93</text>
#
#
#
#
#
#
#
#
#
#       <rect x="136.363636364"
#             y="45.4545454545"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#c4dff0"/>
#
#
#
#           <text x="159.090909091" y="68.1818181818" dominant-baseline="middle" text-anchor="middle" fill="#000">18</text>
#
#
#
#
#
#
#
#
#
#       <rect x="181.818181818"
#             y="45.4545454545"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#dfeef8"/>
#
#
#
#           <text x="204.545454545" y="68.1818181818" dominant-baseline="middle" text-anchor="middle" fill="#000">9</text>
#
#
#
#
#
#
#
#
#
#       <rect x="227.272727273"
#             y="45.4545454545"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#19467e"/>
#
#
#
#           <text x="250.0" y="68.1818181818" dominant-baseline="middle" text-anchor="middle" fill="#fff">91</text>
#
#
#
#
#
#
#
#
#
#       <rect x="272.727272727"
#             y="45.4545454545"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#1a477f"/>
#
#
#
#           <text x="295.454545455" y="68.1818181818" dominant-baseline="middle" text-anchor="middle" fill="#fff">91</text>
#
#
#
#
#
#
#
#
#
#       <rect x="318.181818182"
#             y="45.4545454545"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#b4d6eb"/>
#
#
#
#           <text x="340.909090909" y="68.1818181818" dominant-baseline="middle" text-anchor="middle" fill="#000">24</text>
#
#
#
#
#
#
#
#
#
#       <rect x="363.636363636"
#             y="45.4545454545"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#154079"/>
#
#
#
#           <text x="386.363636364" y="68.1818181818" dominant-baseline="middle" text-anchor="middle" fill="#fff">94</text>
#
#
#
#
#
#
#
#
#
#       <rect x="409.090909091"
#             y="45.4545454545"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#113b75"/>
#
#
#
#           <text x="431.818181818" y="68.1818181818" dominant-baseline="middle" text-anchor="middle" fill="#fff">96</text>
#
#
#
#
#
#
#
#
#
#       <rect x="454.545454545"
#             y="45.4545454545"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#bcdbee"/>
#
#
#
#           <text x="477.272727273" y="68.1818181818" dominant-baseline="middle" text-anchor="middle" fill="#000">21</text>
#
#
#
#
#
#
#     <text class="title" x="505" y="68.1818181818" text-anchor="start" dominant-baseline="middle">Chad</text>
#
#
#
#
#
#
#
#       <rect x="0.0"
#             y="90.9090909091"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#113b75"/>
#
#
#
#
#
#
#
#
#
#
#
#
#       <rect x="45.4545454545"
#             y="90.9090909091"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#154079"/>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       <rect x="136.363636364"
#             y="90.9090909091"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#0c356f"/>
#
#
#
#           <text x="159.090909091" y="113.636363636" dominant-baseline="middle" text-anchor="middle" fill="#fff">98</text>
#
#
#
#
#
#
#
#
#
#       <rect x="181.818181818"
#             y="90.9090909091"
#         width="45.4545454545"
#        height="45.4545454545" stroke="#fff" fill="#143f78"/>
#
#
#
#           <text x="204.545
